# %%
import numpy as np
import matplotlib.pyplot as plt
import glob as glob
import pandas as pd

# %%
from ISpy.assess import location
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
loc=location.nnloc_read('loc.Ant__RunNLLoc000.20200114.000021.grid0.loc.hyp')
# Out:
# "LOCATED"
# [-1.59769]

# %%
loc_pd=pd.DataFrame(loc)

# %%
print(loc_pd)
# Out:
#       East     North    Depth     Stdxx     Stdyy     Stdzz
# 0 -1.59769  0.088688  1.80156  2.620809  4.025233  0.028545

# %%
stations={'Name':['t1','t2','t3'],'East':[-2.2,-1.5,-1],'North':[0.5,-0.5,0.5],'Depth':[0,0,0]}
stations=pd.DataFrame(stations)

# %%
location.loc_plot(loc_pd,stations)
